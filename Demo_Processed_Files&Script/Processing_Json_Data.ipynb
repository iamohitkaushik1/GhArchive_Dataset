# %% [markdown]
# # Importing Necessary Libraries

# %%
import pandas as pd
import json

# %% [markdown]
# # Reading Data

# %%
def read_large_json(file_path, chunksize=10000):
    """Reads a large JSON file in chunks and yields DataFrames.

    Args:
        file_path (str): Path to the JSON file.
        chunksize (int, optional): Number of lines to read at a time. Defaults to 1000.

    Yields:
        pandas.DataFrame: A chunk of the data as a DataFrame.
    """

    with open(file_path, "r", encoding="utf-8") as file:
        reader = pd.read_json(file, lines=True, chunksize=chunksize)
        for chunk in reader:
            yield chunk

# Example usage
data = pd.DataFrame()
for chunk in read_large_json("D:/GhArchive/Demo_Processed_Files&Script/2023-01-01-0.json"):    # or get the demo file here: https://drive.google.com/file/d/11lUM4tU1sRsgMwvE-AFwkWKnW9vpS_r3/view
    data = pd.concat([data, chunk], ignore_index=True)

data.head()  # View the first few rows
# Out:
#             id         type  \
# 0  26163418658    PushEvent
# 1  26163418659    PushEvent
# 2  26163418660  IssuesEvent
# 3  26163418664   WatchEvent
# 4  26163418665    PushEvent
#
#                                                actor  \
# 0  {'id': 119809980, 'login': 'ehwu106', 'display...
# 1  {'id': 77187908, 'login': 'Cefqrn', 'display_l...
# 2  {'id': 121737278, 'login': 'LaymooDR', 'displa...
# 3  {'id': 89544871, 'login': 'Aziz403', 'display_...
# 4  {'id': 8517910, 'login': 'LombiqBot', 'display...
#
#                                                 repo  \
# 0  {'id': 582174284, 'name': 'ehwu106/Gmail-Filte...
# 1  {'id': 583140987, 'name': 'Cefqrn/pyxpr', 'url...
# 2  {'id': 383940088, 'name': 'ShadowMario/FNF-Psy...
# 3  {'id': 2663796, 'name': 'lexik/LexikTranslatio...
# 4  {'id': 410004154, 'name': 'Lombiq/TheBootstrap...
#
#                                              payload  public  \
# 0  {'push_id': 12147229638, 'size': 2, 'distinct_...    True
# 1  {'push_id': 12147229637, 'size': 2, 'distinct_...    True
# 2  {'action': 'opened', 'issue': {'url': 'https:/...    True
# 3                              {'action': 'started'}    True
# 4  {'push_id': 12147229641, 'size': 0, 'distinct_...    True
#
#                  created_at                                                org
# 0 2023-01-01 00:00:00+00:00                                                NaN
# 1 2023-01-01 00:00:00+00:00                                                NaN
# 2 2023-01-01 00:00:00+00:00                                                NaN
# 3 2023-01-01 00:00:00+00:00  {'id': 568486, 'login': 'lexik', 'gravatar_id'...
# 4 2023-01-01 00:00:00+00:00  {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...

# %%
data
# Out:
#                  id                           type  \
# 0       26163418658                      PushEvent
# 1       26163418659                      PushEvent
# 2       26163418660                    IssuesEvent
# 3       26163418664                     WatchEvent
# 4       26163418665                      PushEvent
# ...             ...                            ...
# 101912  26163700494                      PushEvent
# 101913  26163700498                      PushEvent
# 101914  26163700502              IssueCommentEvent
# 101915  26163700504                      PushEvent
# 101916  26163701098  PullRequestReviewCommentEvent
#
#                                                     actor  \
# 0       {'id': 119809980, 'login': 'ehwu106', 'display...
# 1       {'id': 77187908, 'login': 'Cefqrn', 'display_l...
# 2       {'id': 121737278, 'login': 'LaymooDR', 'displa...
# 3       {'id': 89544871, 'login': 'Aziz403', 'display_...
# 4       {'id': 8517910, 'login': 'LombiqBot', 'display...
# ...                                                   ...
# 101912  {'id': 93773753, 'login': 'BlaaSwe', 'display_...
# 101913  {'id': 110655703, 'login': 'sfj297092319', 'di...
# 101914  {'id': 55374212, 'login': 'GuillaumePrata', 'd...
# 101915  {'id': 35409597, 'login': 'JetBlack011', 'disp...
# 101916  {'id': 17688683, 'login': 'Amazinite', 'displa...
#
#                                                      repo  \
# 0       {'id': 582174284, 'name': 'ehwu106/Gmail-Filte...
# 1       {'id': 583140987, 'name': 'Cefqrn/pyxpr', 'url...
# 2       {'id': 383940088, 'name': 'ShadowMario/FNF-Psy...
# 3       {'id': 2663796, 'name': 'lexik/LexikTranslatio...
# 4       {'id': 410004154, 'name': 'Lombiq/TheBootstrap...
# ...                                                   ...
# 101912  {'id': 568383720, 'name': 'BlaaSwe/Base-Soarin...
# 101913  {'id': 530264309, 'name': 'usahexo/2452bb12a82...
# 101914  {'id': 3234987, 'name': 'tgstation/tgstation',...
# 101915  {'id': 541393257, 'name': 'JetBlack011/convex-...
# 101916  {'id': 32231207, 'name': 'endless-sky/endless-...
#
#                                                   payload  public  \
# 0       {'push_id': 12147229638, 'size': 2, 'distinct_...    True
# 1       {'push_id': 12147229637, 'size': 2, 'distinct_...    True
# 2       {'action': 'opened', 'issue': {'url': 'https:/...    True
# 3                                   {'action': 'started'}    True
# 4       {'push_id': 12147229641, 'size': 0, 'distinct_...    True
# ...                                                   ...     ...
# 101912  {'push_id': 12147404982, 'size': 1, 'distinct_...    True
# 101913  {'push_id': 12147404988, 'size': 1, 'distinct_...    True
# 101914  {'action': 'created', 'issue': {'url': 'https:...    True
# 101915  {'push_id': 12147404989, 'size': 1, 'distinct_...    True
# 101916  {'action': 'created', 'comment': {'url': 'http...    True
#
#                       created_at  \
# 0      2023-01-01 00:00:00+00:00
# 1      2023-01-01 00:00:00+00:00
# 2      2023-01-01 00:00:00+00:00
# 3      2023-01-01 00:00:00+00:00
# 4      2023-01-01 00:00:00+00:00
# ...                          ...
# 101912 2023-01-01 00:59:59+00:00
# 101913 2023-01-01 00:59:59+00:00
# 101914 2023-01-01 00:59:59+00:00
# 101915 2023-01-01 00:59:59+00:00
# 101916 2023-01-01 00:59:05+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       {'id': 568486, 'login': 'lexik', 'gravatar_id'...
# 4       {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# ...                                                   ...
# 101912                                                NaN
# 101913  {'id': 110656312, 'login': 'usahexo', 'gravata...
# 101914  {'id': 1363778, 'login': 'tgstation', 'gravata...
# 101915                                                NaN
# 101916  {'id': 11450262, 'login': 'endless-sky', 'grav...
#
# [101917 rows x 8 columns]

# %% [markdown]
# # Checking Data Information

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101917 entries, 0 to 101916
# Data columns (total 8 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   id          101917 non-null  int64
#  1   type        101917 non-null  object
#  2   actor       101917 non-null  object
#  3   repo        101917 non-null  object
#  4   payload     101917 non-null  object
#  5   public      101917 non-null  bool
#  6   created_at  101917 non-null  datetime64[ns, UTC]
#  7   org         25639 non-null   object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(1), object(5)
# memory usage: 5.5+ MB

# %% [markdown]
# # Type of Events

# %%
data['type'].value_counts()
# Out:
# type
# PushEvent                        61501
# CreateEvent                      12414
# PullRequestEvent                 10440
# IssueCommentEvent                 5414
# DeleteEvent                       4019
# WatchEvent                        3023
# IssuesEvent                       1610
# PullRequestReviewEvent             832
# ForkEvent                          747
# ReleaseEvent                       743
# CommitCommentEvent                 593
# PullRequestReviewCommentEvent      281
# PublicEvent                        146
# GollumEvent                        105
# MemberEvent                         49
# Name: count, dtype: int64

# %% [markdown]
# # Extracting Repository Information

# %%
# Extracting values from the 'repo' column
repo_df = pd.json_normalize(data['repo'])

# %%
repo_df
# Out:
#                id                             name  \
# 0       582174284    ehwu106/Gmail-Filter-Solution
# 1       583140987                     Cefqrn/pyxpr
# 2       383940088      ShadowMario/FNF-PsychEngine
# 3         2663796     lexik/LexikTranslationBundle
# 4       410004154         Lombiq/TheBootstrapTheme
# ...           ...                              ...
# 101912  568383720  BlaaSwe/Base-Soaring-Signalytic
# 101913  530264309            usahexo/2452bb12a8217
# 101914    3234987              tgstation/tgstation
# 101915  541393257    JetBlack011/convex-structures
# 101916   32231207          endless-sky/endless-sky
#
#                                                       url
# 0       https://api.github.com/repos/ehwu106/Gmail-Fil...
# 1               https://api.github.com/repos/Cefqrn/pyxpr
# 2       https://api.github.com/repos/ShadowMario/FNF-P...
# 3       https://api.github.com/repos/lexik/LexikTransl...
# 4       https://api.github.com/repos/Lombiq/TheBootstr...
# ...                                                   ...
# 101912  https://api.github.com/repos/BlaaSwe/Base-Soar...
# 101913  https://api.github.com/repos/usahexo/2452bb12a...
# 101914   https://api.github.com/repos/tgstation/tgstation
# 101915  https://api.github.com/repos/JetBlack011/conve...
# 101916  https://api.github.com/repos/endless-sky/endle...
#
# [101917 rows x 3 columns]

# %%
repo_df['name'].nunique()
# Out:
# 43782

# %%
repo_df['name'].value_counts()
# Out:
# name
# Lombiq/Orchard                           1398
# unifyai/ivy                               885
# B4kedBr3ad/yo                             605
# Rolleander/yoyo_mirror                    585
# thoth-station/prescriptions               583
#                                          ...
# x3fang/x3fang.github.io                     1
# DatBoiTim/DBT-BeeStation                    1
# cool-RR/PySnooper                           1
# enricopolanski/functional-programming       1
# JetBlack011/convex-structures               1
# Name: count, Length: 43782, dtype: int64

# %%
id = data['id']

# %%
id
# Out:
# 0         26163418658
# 1         26163418659
# 2         26163418660
# 3         26163418664
# 4         26163418665
#              ...
# 101912    26163700494
# 101913    26163700498
# 101914    26163700502
# 101915    26163700504
# 101916    26163701098
# Name: id, Length: 101917, dtype: int64

# %%
repo_df.columns= ['repo_id', 'repo_name', 'repo_url']

# %%
repo_info = pd.concat([id, repo_df], axis=1)

# %%
repo_info
# Out:
#                  id    repo_id                        repo_name  \
# 0       26163418658  582174284    ehwu106/Gmail-Filter-Solution
# 1       26163418659  583140987                     Cefqrn/pyxpr
# 2       26163418660  383940088      ShadowMario/FNF-PsychEngine
# 3       26163418664    2663796     lexik/LexikTranslationBundle
# 4       26163418665  410004154         Lombiq/TheBootstrapTheme
# ...             ...        ...                              ...
# 101912  26163700494  568383720  BlaaSwe/Base-Soaring-Signalytic
# 101913  26163700498  530264309            usahexo/2452bb12a8217
# 101914  26163700502    3234987              tgstation/tgstation
# 101915  26163700504  541393257    JetBlack011/convex-structures
# 101916  26163701098   32231207          endless-sky/endless-sky
#
#                                                  repo_url
# 0       https://api.github.com/repos/ehwu106/Gmail-Fil...
# 1               https://api.github.com/repos/Cefqrn/pyxpr
# 2       https://api.github.com/repos/ShadowMario/FNF-P...
# 3       https://api.github.com/repos/lexik/LexikTransl...
# 4       https://api.github.com/repos/Lombiq/TheBootstr...
# ...                                                   ...
# 101912  https://api.github.com/repos/BlaaSwe/Base-Soar...
# 101913  https://api.github.com/repos/usahexo/2452bb12a...
# 101914   https://api.github.com/repos/tgstation/tgstation
# 101915  https://api.github.com/repos/JetBlack011/conve...
# 101916  https://api.github.com/repos/endless-sky/endle...
#
# [101917 rows x 4 columns]

# %%
repo_info.to_csv('D:/GhArchive/Demo_Processed_Files&Script/repo_info.csv', index= False)

# %% [markdown]
# # Group data according to event types

# %%
data['type'].value_counts()
# Out:
# type
# PushEvent                        61501
# CreateEvent                      12414
# PullRequestEvent                 10440
# IssueCommentEvent                 5414
# DeleteEvent                       4019
# WatchEvent                        3023
# IssuesEvent                       1610
# PullRequestReviewEvent             832
# ForkEvent                          747
# ReleaseEvent                       743
# CommitCommentEvent                 593
# PullRequestReviewCommentEvent      281
# PublicEvent                        146
# GollumEvent                        105
# MemberEvent                         49
# Name: count, dtype: int64

# %% [markdown]
# ## Push Events

# %%
push_events= data[data['type']=='PushEvent']

# %%
push_events
# Out:
#                  id       type  \
# 0       26163418658  PushEvent
# 1       26163418659  PushEvent
# 4       26163418665  PushEvent
# 5       26163418667  PushEvent
# 6       26163418668  PushEvent
# ...             ...        ...
# 101910  26163700491  PushEvent
# 101911  26163700492  PushEvent
# 101912  26163700494  PushEvent
# 101913  26163700498  PushEvent
# 101915  26163700504  PushEvent
#
#                                                     actor  \
# 0       {'id': 119809980, 'login': 'ehwu106', 'display...
# 1       {'id': 77187908, 'login': 'Cefqrn', 'display_l...
# 4       {'id': 8517910, 'login': 'LombiqBot', 'display...
# 5       {'id': 41898282, 'login': 'github-actions[bot]...
# 6       {'id': 118964436, 'login': 'SS7SS', 'display_l...
# ...                                                   ...
# 101910  {'id': 91348256, 'login': 'Pho86', 'display_lo...
# 101911  {'id': 121700457, 'login': 'jessieaaguirre', '...
# 101912  {'id': 93773753, 'login': 'BlaaSwe', 'display_...
# 101913  {'id': 110655703, 'login': 'sfj297092319', 'di...
# 101915  {'id': 35409597, 'login': 'JetBlack011', 'disp...
#
#                                                      repo  \
# 0       {'id': 582174284, 'name': 'ehwu106/Gmail-Filte...
# 1       {'id': 583140987, 'name': 'Cefqrn/pyxpr', 'url...
# 4       {'id': 410004154, 'name': 'Lombiq/TheBootstrap...
# 5       {'id': 250035045, 'name': 'ZamulaK/COVID-19', ...
# 6       {'id': 583726411, 'name': 'SS7SS/Quran_Linux',...
# ...                                                   ...
# 101910  {'id': 553257090, 'name': 'Pho86/WaterTracker'...
# 101911  {'id': 583801195, 'name': 'jessieaaguirre/cv',...
# 101912  {'id': 568383720, 'name': 'BlaaSwe/Base-Soarin...
# 101913  {'id': 530264309, 'name': 'usahexo/2452bb12a82...
# 101915  {'id': 541393257, 'name': 'JetBlack011/convex-...
#
#                                                   payload  public  \
# 0       {'push_id': 12147229638, 'size': 2, 'distinct_...    True
# 1       {'push_id': 12147229637, 'size': 2, 'distinct_...    True
# 4       {'push_id': 12147229641, 'size': 0, 'distinct_...    True
# 5       {'push_id': 12147229642, 'size': 1, 'distinct_...    True
# 6       {'push_id': 12147229640, 'size': 1, 'distinct_...    True
# ...                                                   ...     ...
# 101910  {'push_id': 12147404986, 'size': 1, 'distinct_...    True
# 101911  {'push_id': 12147404983, 'size': 1, 'distinct_...    True
# 101912  {'push_id': 12147404982, 'size': 1, 'distinct_...    True
# 101913  {'push_id': 12147404988, 'size': 1, 'distinct_...    True
# 101915  {'push_id': 12147404989, 'size': 1, 'distinct_...    True
#
#                       created_at  \
# 0      2023-01-01 00:00:00+00:00
# 1      2023-01-01 00:00:00+00:00
# 4      2023-01-01 00:00:00+00:00
# 5      2023-01-01 00:00:00+00:00
# 6      2023-01-01 00:00:00+00:00
# ...                          ...
# 101910 2023-01-01 00:59:59+00:00
# 101911 2023-01-01 00:59:59+00:00
# 101912 2023-01-01 00:59:59+00:00
# 101913 2023-01-01 00:59:59+00:00
# 101915 2023-01-01 00:59:59+00:00
#
#                                                       org
# 0                                                     NaN
# 1                                                     NaN
# 4       {'id': 8158177, 'login': 'Lombiq', 'gravatar_i...
# 5                                                     NaN
# 6                                                     NaN
# ...                                                   ...
# 101910                                                NaN
# 101911                                                NaN
# 101912                                                NaN
# 101913  {'id': 110656312, 'login': 'usahexo', 'gravata...
# 101915                                                NaN
#
# [61501 rows x 8 columns]

# %%
push_events.isnull().sum()
# Out:
# id                0
# type              0
# actor             0
# repo              0
# payload           0
# public            0
# created_at        0
# org           49010
# dtype: int64

# %%
push_events.drop(columns=['org'], inplace=True)
# Out:
# C:\Users\Asus\AppData\Local\Temp\ipykernel_11256\3155883651.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   push_events.drop(columns=['org'], inplace=True)

# %%
push_events.isnull().sum()
# Out:
# id            0
# type          0
# actor         0
# repo          0
# payload       0
# public        0
# created_at    0
# dtype: int64

# %%
push_id = push_events ['Id']

# %%
# Normalize the 'actor' column
push_actor_df = pd.json_normalize(push_events['actor'])

# Rename the columns to include the prefix 'actor_'
push_actor_df.columns = [f"actor_{col}" for col in push_actor_df.columns]


# Reset the index of 'push_id' and 'push_actor_df'
push_id.reset_index(drop=True, inplace=True)
push_actor_df.reset_index(drop=True, inplace=True)

# Concatenate 'push_id' with 'push_actor_df'
push_actor_df = pd.concat([push_id, push_actor_df], axis=1)

# Display the shape of the concatenated DataFrame
print(push_actor_df.shape)
# Out:
# (61501, 7)

# %%
push_id
# Out:
# 0         26163418658
# 1         26163418659
# 4         26163418665
# 5         26163418667
# 6         26163418668
#              ...
# 101910    26163700491
# 101911    26163700492
# 101912    26163700494
# 101913    26163700498
# 101915    26163700504
# Name: Id, Length: 61501, dtype: int64

# %%
push_actor_df
# Out:
#                   0            1                    2               3 4   \
# 0      2.616342e+10  119809980.0              ehwu106         ehwu106
# 1      2.616342e+10   77187908.0               Cefqrn          Cefqrn
# 4      2.616342e+10  118964436.0                SS7SS           SS7SS
# 5      2.616342e+10   41898282.0  github-actions[bot]  github-actions
# 6      2.616342e+10   21151734.0             drphil3d        drphil3d
# ...             ...          ...                  ...             ... ..
# 61485           NaN   41898282.0  github-actions[bot]  github-actions
# 61487           NaN    8581566.0                FRE3X           FRE3X
# 61491           NaN   41898282.0  github-actions[bot]  github-actions
# 61495           NaN   41898282.0  github-actions[bot]  github-actions
# 61499           NaN  110655703.0         sfj297092319    sfj297092319
#
#                                                       5  \
# 0                  https://api.github.com/users/ehwu106
# 1                   https://api.github.com/users/Cefqrn
# 4                    https://api.github.com/users/SS7SS
# 5      https://api.github.com/users/github-actions[bot]
# 6                 https://api.github.com/users/drphil3d
# ...                                                 ...
# 61485  https://api.github.com/users/github-actions[bot]
# 61487                https://api.github.com/users/FRE3X
# 61491  https://api.github.com/users/github-actions[bot]
# 61495  https://api.github.com/users/github-actions[bot]
# 61499         https://api.github.com/users/sfj297092319
#
#                                                        6
# 0      https://avatars.githubusercontent.com/u/119809...
# 1      https://avatars.githubusercontent.com/u/77187908?
# 4      https://avatars.githubusercontent.com/u/118964...
# 5      https://avatars.githubusercontent.com/u/41898282?
# 6      https://avatars.githubusercontent.com/u/21151734?
# ...                                                  ...
# 61485  https://avatars.githubusercontent.com/u/41898282?
# 61487   https://avatars.githubusercontent.com/u/8581566?
# 61491  https://avatars.githubusercontent.com/u/41898282?
# 61495  https://avatars.githubusercontent.com/u/41898282?
# 61499  https://avatars.githubusercontent.com/u/110655...
#
# [90065 rows x 7 columns]

# %%
# Normalize the 'actor' column
push_repo_df = pd.json_normalize(push_events['repo'])

# Rename the columns to include the prefix 'actor_'
push_repo_df.columns = [f"repo_{col}" for col in push_repo_df.columns]

#push_actor_df = pd.concat([push_id, push_actor_df], axis= 1)

# %%
# Normalize the 'actor' column
push_payload_df = pd.json_normalize(push_events['payload'])

# Rename the columns to include the prefix 'actor_'
push_payload_df.columns = [f"payload_{col}" for col in push_payload_df.columns]

# %%
push_actor_df.isnull().sum()
# Out:
# actor_id               0
# actor_login            0
# actor_display_login    0
# actor_gravatar_id      0
# actor_url              0
# actor_avatar_url       0
# dtype: int64

# %%
push_repo_df.isnull().sum()
# Out:
# repo_id      0
# repo_name    0
# repo_url     0
# dtype: int64

# %%
push_payload_df.isnull().sum()
# Out:
# payload_push_id          0
# payload_size             0
# payload_distinct_size    0
# payload_ref              0
# payload_head             0
# payload_before           0
# payload_commits          0
# dtype: int64

# %%
push_info.isnull().sum()
# Out:
# Id            0
# type          0
# created_at    0
# dtype: int64

# %%
push_events.columns
# Out:
# Index(['Id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at'], dtype='object')

# %%
push_events.columns= ['Id', 'type', 'actor', 'repo', 'payload', 'public', 'created_at']

# %%
push_info= push_events [['Id', 'type', 'created_at']]

# %%
# Reset the indices of all DataFrames
push_info.reset_index(drop=True, inplace=True)
push_actor_df.reset_index(drop=True, inplace=True)
push_repo_df.reset_index(drop=True, inplace=True)
push_payload_df.reset_index(drop=True, inplace=True)

# Concatenate the DataFrames to create 'push_event_detailed'
push_event_detailed = pd.concat([push_info, push_actor_df, push_repo_df, push_payload_df], axis=1)

# %%
push_event_detailed
# Out:
#                 Id       type                created_at           Id  \
# 0      26163418658  PushEvent 2023-01-01 00:00:00+00:00  26163418658
# 1      26163418659  PushEvent 2023-01-01 00:00:00+00:00  26163418659
# 2      26163418665  PushEvent 2023-01-01 00:00:00+00:00  26163418665
# 3      26163418667  PushEvent 2023-01-01 00:00:00+00:00  26163418667
# 4      26163418668  PushEvent 2023-01-01 00:00:00+00:00  26163418668
# ...            ...        ...                       ...          ...
# 61496  26163700491  PushEvent 2023-01-01 00:59:59+00:00  26163700491
# 61497  26163700492  PushEvent 2023-01-01 00:59:59+00:00  26163700492
# 61498  26163700494  PushEvent 2023-01-01 00:59:59+00:00  26163700494
# 61499  26163700498  PushEvent 2023-01-01 00:59:59+00:00  26163700498
# 61500  26163700504  PushEvent 2023-01-01 00:59:59+00:00  26163700504
#
#         actor_id          actor_login actor_display_login actor_gravatar_id  \
# 0      119809980              ehwu106             ehwu106
# 1       77187908               Cefqrn              Cefqrn
# 2        8517910            LombiqBot           LombiqBot
# 3       41898282  github-actions[bot]      github-actions
# 4      118964436                SS7SS               SS7SS
# ...          ...                  ...                 ...               ...
# 61496   91348256                Pho86               Pho86
# 61497  121700457       jessieaaguirre      jessieaaguirre
# 61498   93773753              BlaaSwe             BlaaSwe
# 61499  110655703         sfj297092319        sfj297092319
# 61500   35409597          JetBlack011         JetBlack011
#
#                                               actor_url  \
# 0                  https://api.github.com/users/ehwu106
# 1                   https://api.github.com/users/Cefqrn
# 2                https://api.github.com/users/LombiqBot
# 3      https://api.github.com/users/github-actions[bot]
# 4                    https://api.github.com/users/SS7SS
# ...                                                 ...
# 61496                https://api.github.com/users/Pho86
# 61497       https://api.github.com/users/jessieaaguirre
# 61498              https://api.github.com/users/BlaaSwe
# 61499         https://api.github.com/users/sfj297092319
# 61500          https://api.github.com/users/JetBlack011
#
#                                         actor_avatar_url    repo_id  \
# 0      https://avatars.githubusercontent.com/u/119809...  582174284
# 1      https://avatars.githubusercontent.com/u/77187908?  583140987
# 2       https://avatars.githubusercontent.com/u/8517910?  410004154
# 3      https://avatars.githubusercontent.com/u/41898282?  250035045
# 4      https://avatars.githubusercontent.com/u/118964...  583726411
# ...                                                  ...        ...
# 61496  https://avatars.githubusercontent.com/u/91348256?  553257090
# 61497  https://avatars.githubusercontent.com/u/121700...  583801195
# 61498  https://avatars.githubusercontent.com/u/93773753?  568383720
# 61499  https://avatars.githubusercontent.com/u/110655...  530264309
# 61500  https://avatars.githubusercontent.com/u/35409597?  541393257
#
#                              repo_name  \
# 0        ehwu106/Gmail-Filter-Solution
# 1                         Cefqrn/pyxpr
# 2             Lombiq/TheBootstrapTheme
# 3                     ZamulaK/COVID-19
# 4                    SS7SS/Quran_Linux
# ...                                ...
# 61496               Pho86/WaterTracker
# 61497                jessieaaguirre/cv
# 61498  BlaaSwe/Base-Soaring-Signalytic
# 61499            usahexo/2452bb12a8217
# 61500    JetBlack011/convex-structures
#
#                                                 repo_url  payload_push_id  \
# 0      https://api.github.com/repos/ehwu106/Gmail-Fil...      12147229638
# 1              https://api.github.com/repos/Cefqrn/pyxpr      12147229637
# 2      https://api.github.com/repos/Lombiq/TheBootstr...      12147229641
# 3          https://api.github.com/repos/ZamulaK/COVID-19      12147229642
# 4         https://api.github.com/repos/SS7SS/Quran_Linux      12147229640
# ...                                                  ...              ...
# 61496    https://api.github.com/repos/Pho86/WaterTracker      12147404986
# 61497     https://api.github.com/repos/jessieaaguirre/cv      12147404983
# 61498  https://api.github.com/repos/BlaaSwe/Base-Soar...      12147404982
# 61499  https://api.github.com/repos/usahexo/2452bb12a...      12147404988
# 61500  https://api.github.com/repos/JetBlack011/conve...      12147404989
#
#        payload_size  payload_distinct_size          payload_ref  \
# 0                 2                      2      refs/heads/main
# 1                 2                      2      refs/heads/main
# 2                 0                      0    refs/heads/master
# 3                 1                      1  refs/heads/web-data
# 4                 1                      1   refs/heads/tepthon
# ...             ...                    ...                  ...
# 61496             1                      1      refs/heads/main
# 61497             1                      1      refs/heads/main
# 61498             1                      1      refs/heads/main
# 61499             1                      1      refs/heads/main
# 61500             1                      1      refs/heads/main
#
#                                    payload_head  \
# 0      8fbcb0a5be7f1ae98c620ffc445f8212da279c4b
# 1      f64e5c366a20276fd1499cc485e131c08aeba5ee
# 2      1c0d357e00552ca5a53e2a94573fd9d6f73fcdf5
# 3      95bf957f5188641598151af8c35872686f18bd85
# 4      2585e306dd64c4b529956550bd2e48467d211fd7
# ...                                         ...
# 61496  b68cbbbaf8cc41cc91d8bf99074ee21cd41c3593
# 61497  28428ae14ec1d1f3b6fc22961a8a682f926fce79
# 61498  2f9e119720495cc866feee8917395918f42822c1
# 61499  d44bb3277a08429d0069dfd24db8adc3f0967bb9
# 61500  05c1305270119979bb08630b63d05ae1150f656b
#
#                                  payload_before  \
# 0      27e76fd2920c98cf825daefa9469cb202944d96d
# 1      367a5d47552f98e7acffe2f20b9a8c82f34f71a9
# 2      1c0d357e00552ca5a53e2a94573fd9d6f73fcdf5
# 3      db49e743d0ea2ce8aa87ebfd2de9936853a1ba95
# 4      39b84f330971e62a6b4d7931f4cbbe045e55c3af
# ...                                         ...
# 61496  3a3b3709264cdbfa4b2887a36c56cb684c04dfa1
# 61497  11aabbc69f0941f38b3905cfb7f366390611656f
# 61498  6ec62036c0ce829f587df3bf5df78729bab83420
# 61499  2357ef55a5d425323c3be174545fdedf56042ab8
# 61500  f58a1b5118b175e1d9875ed9859ce5e3a97b00ef
#
#                                          payload_commits
# 0      [{'sha': '01882b15808c6cc63f4075eea105de4f608e...
# 1      [{'sha': '61696611ba5a9edd83c997d8a6cc477fa483...
# 2                                                     []
# 3      [{'sha': '95bf957f5188641598151af8c35872686f18...
# 4      [{'sha': '2585e306dd64c4b529956550bd2e48467d21...
# ...                                                  ...
# 61496  [{'sha': 'b68cbbbaf8cc41cc91d8bf99074ee21cd41c...
# 61497  [{'sha': '28428ae14ec1d1f3b6fc22961a8a682f926f...
# 61498  [{'sha': '2f9e119720495cc866feee8917395918f428...
# 61499  [{'sha': 'd44bb3277a08429d0069dfd24db8adc3f096...
# 61500  [{'sha': '05c1305270119979bb08630b63d05ae1150f...
#
# [61501 rows x 20 columns]

# %%
push_event_detailed.isnull().sum()
# Out:
# Id                       0
# type                     0
# created_at               0
# Id                       0
# actor_id                 0
# actor_login              0
# actor_display_login      0
# actor_gravatar_id        0
# actor_url                0
# actor_avatar_url         0
# repo_id                  0
# repo_name                0
# repo_url                 0
# payload_push_id          0
# payload_size             0
# payload_distinct_size    0
# payload_ref              0
# payload_head             0
# payload_before           0
# payload_commits          0
# dtype: int64

# %% [markdown]
# ### Further Normalizing Payload Commit Info

# %%
push_event_detailed.columns
# Out:
# Index(['Id', 'type', 'created_at', 'Id', 'actor_id', 'actor_login',
#        'actor_display_login', 'actor_gravatar_id', 'actor_url',
#        'actor_avatar_url', 'repo_id', 'repo_name', 'repo_url',
#        'payload_push_id', 'payload_size', 'payload_distinct_size',
#        'payload_ref', 'payload_head', 'payload_before', 'payload_commits'],
#       dtype='object')

# %%
push_event_detailed.isnull().sum()
# Out:
# Id                       0
# type                     0
# created_at               0
# Id                       0
# actor_id                 0
# actor_login              0
# actor_display_login      0
# actor_gravatar_id        0
# actor_url                0
# actor_avatar_url         0
# repo_id                  0
# repo_name                0
# repo_url                 0
# payload_push_id          0
# payload_size             0
# payload_distinct_size    0
# payload_ref              0
# payload_head             0
# payload_before           0
# payload_commits          0
# dtype: int64

# %%
push_event_detailed.columns
# Out:
# Index(['Id', 'type', 'created_at', 'Id', 'actor_id', 'actor_login',
#        'actor_display_login', 'actor_gravatar_id', 'actor_url',
#        'actor_avatar_url', 'repo_id', 'repo_name', 'repo_url',
#        'payload_push_id', 'payload_size', 'payload_distinct_size',
#        'payload_ref', 'payload_head', 'payload_before', 'payload_commits'],
#       dtype='object')

# %%
push_event_detailed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61501 entries, 0 to 61500
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     61501 non-null  int64
#  1   type                   61501 non-null  object
#  2   created_at             61501 non-null  datetime64[ns, UTC]
#  3   Id                     61501 non-null  int64
#  4   actor_id               61501 non-null  int64
#  5   actor_login            61501 non-null  object
#  6   actor_display_login    61501 non-null  object
#  7   actor_gravatar_id      61501 non-null  object
#  8   actor_url              61501 non-null  object
#  9   actor_avatar_url       61501 non-null  object
#  10  repo_id                61501 non-null  int64
#  11  repo_name              61501 non-null  object
#  12  repo_url               61501 non-null  object
#  13  payload_push_id        61501 non-null  int64
#  14  payload_size           61501 non-null  int64
#  15  payload_distinct_size  61501 non-null  int64
#  16  payload_ref            61501 non-null  object
#  17  payload_head           61501 non-null  object
#  18  payload_before         61501 non-null  object
#  19  payload_commits        61501 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(7), object(12)
# memory usage: 9.4+ MB

# %%
# Normalize the 'actor' column
push_payload_commits_df = pd.json_normalize(push_event_detailed['payload_commits'])

# Rename the columns to include the prefix 'actor_'
push_payload_commits_df.columns = [f"payload_commits{col}" for col in push_payload_commits_df.columns]

# %%
push_payload_commits_df.isnull().sum()
# Out:
# payload_commits0      4454
# payload_commits1     55517
# payload_commits2     59076
# payload_commits3     59663
# payload_commits4     60266
# payload_commits5     60564
# payload_commits6     60720
# payload_commits7     60817
# payload_commits8     60879
# payload_commits9     60931
# payload_commits10    60980
# payload_commits11    61018
# payload_commits12    61037
# payload_commits13    61067
# payload_commits14    61112
# payload_commits15    61129
# payload_commits16    61153
# payload_commits17    61169
# payload_commits18    61179
# payload_commits19    61188
# dtype: int64

# %% [markdown]
# #### It can be processed further, this is not our goal so will continue it later, meanwhile we convert our desired file into csv.

# %%
push_event_detailed.to_csv('D:/GhArchive/Demo_Processed_Files&Script/push_event_detailed.csv', index=False)

# %% [markdown]
# #### As csv file doesn't contain metadata, so we have to save the file as parquet, which store metadata as well, and for giant file it's best to save file as
#
# #### parquet file, due to its memory efficient properties.
#
# #### CSV File Size : 50,128 KB
# #### Parquet File Size: 18,914 KB , this is the significant difference, in our case the file size reduced with 73%

# %%
# Save the DataFrame to a Parquet file
push_event_detailed.to_parquet('D:/GhArchive/Demo_Processed_Files&Script/push_event_detailed.parquet', index=False)

# %% [markdown]
# ### Let's test whether it saves meta_data or not

# %%
push_event_detailed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61501 entries, 0 to 61500
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     61501 non-null  int64
#  1   type                   61501 non-null  object
#  2   created_at             61501 non-null  datetime64[ns, UTC]
#  3   actor_id               61501 non-null  int64
#  4   actor_login            61501 non-null  object
#  5   actor_display_login    61501 non-null  object
#  6   actor_gravatar_id      61501 non-null  object
#  7   actor_url              61501 non-null  object
#  8   actor_avatar_url       61501 non-null  object
#  9   repo_id                61501 non-null  int64
#  10  repo_name              61501 non-null  object
#  11  repo_url               61501 non-null  object
#  12  payload_push_id        61501 non-null  int64
#  13  payload_size           61501 non-null  int64
#  14  payload_distinct_size  61501 non-null  int64
#  15  payload_ref            61501 non-null  object
#  16  payload_head           61501 non-null  object
#  17  payload_before         61501 non-null  object
#  18  payload_commits        61501 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(6), object(12)
# memory usage: 8.9+ MB

# %%
# To read the Parquet file back into a DataFrame
df_from_parquet = pd.read_parquet('D:/GhArchive/Demo_Processed_Files&Script/push_event_detailed.parquet')

# %%
df_from_parquet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61501 entries, 0 to 61500
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id                     61501 non-null  int64
#  1   type                   61501 non-null  object
#  2   created_at             61501 non-null  datetime64[ns, UTC]
#  3   actor_id               61501 non-null  int64
#  4   actor_login            61501 non-null  object
#  5   actor_display_login    61501 non-null  object
#  6   actor_gravatar_id      61501 non-null  object
#  7   actor_url              61501 non-null  object
#  8   actor_avatar_url       61501 non-null  object
#  9   repo_id                61501 non-null  int64
#  10  repo_name              61501 non-null  object
#  11  repo_url               61501 non-null  object
#  12  payload_push_id        61501 non-null  int64
#  13  payload_size           61501 non-null  int64
#  14  payload_distinct_size  61501 non-null  int64
#  15  payload_ref            61501 non-null  object
#  16  payload_head           61501 non-null  object
#  17  payload_before         61501 non-null  object
#  18  payload_commits        61501 non-null  object
# dtypes: datetime64[ns, UTC](1), int64(6), object(12)
# memory usage: 8.9+ MB

# %% [markdown]
# #### Same process can be adpoted for different event analysis like: pull_request_event, create_event and all.

# %% [markdown]
# # Next Event
